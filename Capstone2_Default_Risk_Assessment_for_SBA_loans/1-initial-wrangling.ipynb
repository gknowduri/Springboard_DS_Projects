# %% [markdown]
# # Springboard Capstone 2: Data Wrangling
#
# ## Default Risk for Small Business Loans

# %% [markdown]
# ### Load the Data

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Read in the data. Use `low_memory = False` to surpress warnings about columns of mixed data type.
##df = pd.read_csv('../Data/Raw/SBAnational.csv', low_memory = False)
df = pd.read_csv('.\Data\Raw\SBAnational.csv', low_memory = False)

# %%
# Inspect the dataframe. Scroll to see all columns.
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
#    Term  NoEmp  NewExist  CreateJob  RetainedJob  FranchiseCode  UrbanRural  \
# 0    84      4       2.0          0            0              1           0
# 1    60      2       2.0          0            0              1           0
# 2   180      7       1.0          0            0              1           0
# 3    60      2       1.0          0            0              1           0
# 4   240     14       1.0          7            7              1           0
#
#   RevLineCr LowDoc ChgOffDate DisbursementDate DisbursementGross BalanceGross  \
# 0         N      Y        NaN        28-Feb-99       $60,000.00        $0.00
# 1         N      Y        NaN        31-May-97       $40,000.00        $0.00
# 2         N      N        NaN        31-Dec-97      $287,000.00        $0.00
# 3         N      Y        NaN        30-Jun-97       $35,000.00        $0.00
# 4         N      N        NaN        14-May-97      $229,000.00        $0.00
#
#   MIS_Status ChgOffPrinGr        GrAppv      SBA_Appv
# 0      P I F       $0.00    $60,000.00    $48,000.00
# 1      P I F       $0.00    $40,000.00    $32,000.00
# 2      P I F       $0.00   $287,000.00   $215,250.00
# 3      P I F       $0.00    $35,000.00    $28,000.00
# 4      P I F       $0.00   $229,000.00   $229,000.00

# %% [markdown]
# ### Set column names and data types

# %% [markdown]
# The column names are mostly reasonable. For convenience, we rename `LoanNr_ChkDgt` to `ID`

# %%
df = df.rename(columns = {'LoanNr_ChkDgt': 'ID'})

# %% [markdown]
# We include some additional information from Li, Mickel and Taylor about the less-intuitive column names.
#
# - **NAICS:** Industry classification code.
# - **Term:** Loan term (months)
# - **NoEmp:** Number of employees
# - **NewExist:** 1 for a business that has existed more than two years, 2 for one that has not.
# - **FranchiseCode:** Both 00000 and 00001 mean "no franchise."
# - **UrbanRural:** 1 for urban, 2 for rural, 0 for undefined.
# - **LowDoc:** Whether a low-document application was used (good for loans under \$150,000)

# %%
## List columns that should be converted to each Data Type.
all_cols = list(df.columns)
date_cols = ['ApprovalDate', 'ApprovalFY', 'ChgOffDate', 'DisbursementDate']
int_cols = ['Term', 'NoEmp', 'CreateJob','RetainedJob']
float_cols = ['DisbursementGross', 'BalanceGross', 'GrAppv', 'SBA_Appv', 'ChgOffPrinGr']
cat_cols = list(set(all_cols) - set(date_cols + int_cols + float_cols))

# %%
## Convert columns to category and int as needed
df[cat_cols] = df[cat_cols].apply(lambda x : x.astype('category'))
df[int_cols] = df[int_cols].apply(lambda x : x.astype('int'))

# %%
## Before being converted to float, the columns with dollar amounts must be cleaned to remove special characters.
df[float_cols] = df[float_cols].apply(lambda x: x.str.strip("$"))
df[float_cols] = df[float_cols].apply(lambda x: x.str.replace(",", ""))
df[float_cols] = df[float_cols].apply(lambda x: x.astype('float'))

# %%
# Some loans are listed as having an approval year of 1976A. Change to a valid year.
df['ApprovalFY'] = df['ApprovalFY'].str.strip("A")
df[date_cols] = df[date_cols].apply(lambda x: pd.to_datetime(x, infer_datetime_format = True))

# %%
# We check that data types have been converted successfully, and inspect the DataFrame again.
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899164 entries, 0 to 899163
# Data columns (total 27 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 899164 non-null  category
#  1   Name               899150 non-null  category
#  2   City               899134 non-null  category
#  3   State              899150 non-null  category
#  4   Zip                899164 non-null  category
#  5   Bank               897605 non-null  category
#  6   BankState          897598 non-null  category
#  7   NAICS              899164 non-null  category
#  8   ApprovalDate       899164 non-null  datetime64[ns]
#  9   ApprovalFY         899164 non-null  datetime64[ns]
#  10  Term               899164 non-null  int32
#  11  NoEmp              899164 non-null  int32
#  12  NewExist           899028 non-null  category
#  13  CreateJob          899164 non-null  int32
#  14  RetainedJob        899164 non-null  int32
#  15  FranchiseCode      899164 non-null  category
#  16  UrbanRural         899164 non-null  category
#  17  RevLineCr          894636 non-null  category
#  18  LowDoc             896582 non-null  category
#  19  ChgOffDate         162699 non-null  datetime64[ns]
#  20  DisbursementDate   896796 non-null  datetime64[ns]
#  21  DisbursementGross  899164 non-null  float64
#  22  BalanceGross       899164 non-null  float64
#  23  MIS_Status         897167 non-null  category
#  24  ChgOffPrinGr       899164 non-null  float64
#  25  GrAppv             899164 non-null  float64
#  26  SBA_Appv           899164 non-null  float64
# dtypes: category(14), datetime64[ns](4), float64(5), int32(4)
# memory usage: 162.6 MB
#            ID                           Name          City State    Zip  \
# 0  1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1  1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2  1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3  1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4  1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120   1997-02-28 1997-01-01
# 1                1ST SOURCE BANK        IN  722410   1997-02-28 1997-01-01
# 2        GRANT COUNTY STATE BANK        IN  621210   1997-02-28 1997-01-01
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0   1997-02-28 1997-01-01
# 4        FLORIDA BUS. DEVEL CORP        FL       0   1997-02-28 1997-01-01
#
#    Term  NoEmp NewExist  CreateJob  RetainedJob FranchiseCode UrbanRural  \
# 0    84      4      2.0          0            0             1          0
# 1    60      2      2.0          0            0             1          0
# 2   180      7      1.0          0            0             1          0
# 3    60      2      1.0          0            0             1          0
# 4   240     14      1.0          7            7             1          0
#
#   RevLineCr LowDoc ChgOffDate DisbursementDate  DisbursementGross  \
# 0         N      Y        NaT       1999-02-28            60000.0
# 1         N      Y        NaT       1997-05-31            40000.0
# 2         N      N        NaT       1997-12-31           287000.0
# 3         N      Y        NaT       1997-06-30            35000.0
# 4         N      N        NaT       1997-05-14           229000.0
#
#    BalanceGross MIS_Status  ChgOffPrinGr    GrAppv  SBA_Appv
# 0           0.0      P I F           0.0   60000.0   48000.0
# 1           0.0      P I F           0.0   40000.0   32000.0
# 2           0.0      P I F           0.0  287000.0  215250.0
# 3           0.0      P I F           0.0   35000.0   28000.0
# 4           0.0      P I F           0.0  229000.0  229000.0

# %% [markdown]
# ### Distribution of categorical variables

# %% [markdown]
# We examine the categorical variables. How many values does each one have? What percentage of those values are unique?

# %%
## Subset the categorical variables
categorical = df[cat_cols]

# %%
## Check for the number of unique values in each column
unique_vals = categorical.nunique().sort_values()
unique_vals
# Out:
# MIS_Status            2
# NewExist              3
# UrbanRural            3
# LowDoc                8
# RevLineCr            18
# State                51
# BankState            56
# NAICS              1312
# FranchiseCode      2768
# Bank               5802
# City              32581
# Zip               33611
# Name             779583
# ID               899164
# dtype: int64

# %% [markdown]
# Notice that name has many repeats. This may be a case of different franchises from the same chain getting loans. Also, some of our columns need cleaning. The columns `NewExist`, `LowDoc` and `RevLineCr` should each have only two values. We examine each of these below.

# %%
## Examine the NewExist column
df['NewExist'].value_counts()
# Out:
# 1.0    644869
# 2.0    253125
# 0.0      1034
# Name: NewExist, dtype: int64

# %% [markdown]
# It appears that the value `0.0` means unknown or missing in this column. We replace these values with `NaN.'

# %%
df.loc[df['NewExist'] == 0.0, 'NewExist'] = np.NaN

# %%
## Examine the LowDoc column.
df['LowDoc'].value_counts()
# Out:
# N    782822
# Y    110335
# 0      1491
# C       758
# S       603
# A       497
# R        75
# 1         1
# Name: LowDoc, dtype: int64

# %%
## Replace all values except "N" and "Y" ("No" and "Yes") with NaN.
df.loc[~df['LowDoc'].isin(['N', 'Y']), 'LowDoc'] = np.NaN

# %%
df['RevLineCr'].value_counts()
# Out:
# N    420288
# 0    257602
# Y    201397
# T     15284
# 1        23
# R        14
# `        11
# 2         6
# C         2
# Q         1
# ,         1
# A         1
# -         1
# 5         1
# 4         1
# 3         1
# .         1
# 7         1
# Name: RevLineCr, dtype: int64

# %%
## This column has a large number of values coded 0, which we are not sure how to interpret, so we drop the column entirely.
df.drop(columns = 'RevLineCr', inplace = True)

# %%
df['UrbanRural'].value_counts()
# Out:
# 1    470654
# 0    323167
# 2    105343
# Name: UrbanRural, dtype: int64

# %%
## Having two different codes for 'no franchise' introduces unnecessary noise into our data
df['FranchiseCode'] = df['FranchiseCode'].replace(1, 0)

# %%
## The NAICS code 0 is a missing value. Replace with NaN.
df['NAICS'] = df['NAICS'].replace(0, np.NaN)

# %% [markdown]
# Delete any rows where the response variable `MIS_Status` is missing, as these will not contribute to our final model.

# %%
df.dropna(axis=0, subset=['MIS_Status'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 897167 entries, 0 to 899163
# Data columns (total 26 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 897167 non-null  category
#  1   Name               897153 non-null  category
#  2   City               897137 non-null  category
#  3   State              897154 non-null  category
#  4   Zip                897167 non-null  category
#  5   Bank               895661 non-null  category
#  6   BankState          895654 non-null  category
#  7   NAICS              695500 non-null  category
#  8   ApprovalDate       897167 non-null  datetime64[ns]
#  9   ApprovalFY         897167 non-null  datetime64[ns]
#  10  Term               897167 non-null  int32
#  11  NoEmp              897167 non-null  int32
#  12  NewExist           896005 non-null  category
#  13  CreateJob          897167 non-null  int32
#  14  RetainedJob        897167 non-null  int32
#  15  FranchiseCode      897167 non-null  category
#  16  UrbanRural         897167 non-null  category
#  17  LowDoc             891168 non-null  category
#  18  ChgOffDate         162438 non-null  datetime64[ns]
#  19  DisbursementDate   894992 non-null  datetime64[ns]
#  20  DisbursementGross  897167 non-null  float64
#  21  BalanceGross       897167 non-null  float64
#  22  MIS_Status         897167 non-null  category
#  23  ChgOffPrinGr       897167 non-null  float64
#  24  GrAppv             897167 non-null  float64
#  25  SBA_Appv           897167 non-null  float64
# dtypes: category(13), datetime64[ns](4), float64(5), int32(4)
# memory usage: 168.4 MB

# %% [markdown]
# ### Distribution of numerical and date variables

# %%
## We compute descriptive statistics for the numerical and datetime variables
summary = df.describe(percentiles = [0.25, 0.5, 0.75, 0.90, 0.99], datetime_is_numeric = True).T
summary
# Out:
#                       count                           mean  \
# ApprovalDate         897167  2001-06-02 13:17:21.281723008
# ApprovalFY           897167  2001-02-20 15:18:06.263315712
# Term               897167.0                     110.848592
# NoEmp              897167.0                      11.412562
# CreateJob          897167.0                       8.444305
# RetainedJob        897167.0                      10.807308
# ChgOffDate           162438  2008-07-05 15:27:18.902227456
# DisbursementDate     894992  2001-09-21 14:30:52.773655680
# DisbursementGross  897167.0                  201598.034681
# BalanceGross       897167.0                       2.996003
# ChgOffPrinGr       897167.0                   13527.211002
# GrAppv             897167.0                  193059.516894
# SBA_Appv           897167.0                  149780.698635
#
#                                    min                  25%  \
# ApprovalDate       1974-01-09 00:00:00  1996-11-20 00:00:00
# ApprovalFY         1966-01-01 00:00:00  1997-01-01 00:00:00
# Term                               0.0                 60.0
# NoEmp                              0.0                  2.0
# CreateJob                          0.0                  0.0
# RetainedJob                        0.0                  0.0
# ChgOffDate         1988-10-03 00:00:00  2007-09-06 00:00:00
# DisbursementDate   1974-01-07 00:00:00  1997-05-30 00:00:00
# DisbursementGross               4000.0              42492.0
# BalanceGross                       0.0                  0.0
# ChgOffPrinGr                       0.0                  0.0
# GrAppv                          1000.0              35000.0
# SBA_Appv                         500.0              21250.0
#
#                                    50%                  75%  \
# ApprovalDate       2002-09-26 00:00:00  2006-01-20 00:00:00
# ApprovalFY         2002-01-01 00:00:00  2006-01-01 00:00:00
# Term                              84.0                120.0
# NoEmp                              4.0                 10.0
# CreateJob                          0.0                  1.0
# RetainedJob                        1.0                  4.0
# ChgOffDate         2009-12-04 00:00:00  2011-03-16 00:00:00
# DisbursementDate   2002-12-31 00:00:00  2006-03-31 00:00:00
# DisbursementGross             100000.0             239000.0
# BalanceGross                       0.0                  0.0
# ChgOffPrinGr                       0.0                  0.0
# GrAppv                         90000.0             225000.0
# SBA_Appv                       62050.0             175000.0
#
#                                    90%                  99%  \
# ApprovalDate       2007-11-19 00:00:00  2011-09-27 00:00:00
# ApprovalFY         2008-01-01 00:00:00  2011-01-01 00:00:00
# Term                             240.0                300.0
# NoEmp                             25.0                 95.0
# CreateJob                          5.0                 30.0
# RetainedJob                       11.0                 55.0
# ChgOffDate         2012-09-20 00:00:00  2014-06-19 00:00:00
# DisbursementDate   2008-02-29 00:00:00  2011-12-01 00:00:00
# DisbursementGross             501895.8            1367000.0
# BalanceGross                       0.0                  0.0
# ChgOffPrinGr                   26949.0             276096.4
# GrAppv                        500000.0            1350000.0
# SBA_Appv                      408000.0            1000000.0
#
#                                    max            std
# ApprovalDate       2073-12-20 00:00:00            NaN
# ApprovalFY         2014-01-01 00:00:00            NaN
# Term                             569.0      78.900862
# NoEmp                           9999.0      73.793775
# CreateJob                       8800.0     236.950249
# RetainedJob                     9500.0     237.382398
# ChgOffDate         2026-10-22 00:00:00            NaN
# DisbursementDate   2073-12-24 00:00:00            NaN
# DisbursementGross           11446325.0   287806.62057
# BalanceGross                  996262.0    1443.766066
# ChgOffPrinGr                 3512596.0   65209.860188
# GrAppv                       5472000.0  283433.114425
# SBA_Appv                     5472000.0  228559.979775

# %% [markdown]
# We compute descriptive statistics for the numerical variables, including the date variables. Notice that some dates are in the future, or at least beyond the range of this dataset. The earliest value of `ChgOffDate` is in 1988. It is unlikely that no loans from before that time went into default. So it makes sense to discard data from before 1980. The highest value of `ChgOffDate` is in 2014.
#
# Note that these variables have very different average orders of magnitude. Some transformations will be needed.
# Finally, all of our variables are skewed, with a small number of very high values. Some of these high values are likely data entry errors, but some may be genuine. We delay a decision on these high values for now.

# %%
## Set lower and upper limits for dates
begin_date = dt.datetime.strptime("01-01-1980", "%d-%m-%Y")
end_date = dt.datetime.strptime("31-12-2014", "%d-%m-%Y")

# %%
df = df[~((df['ApprovalDate'] < begin_date) | (df['ApprovalDate'] > end_date))]

# %%
df = df[~((df['ApprovalFY'] < begin_date) | (df['ApprovalFY'] > end_date))]

# %%
df = df[~((df['DisbursementDate'] < begin_date) | (df['DisbursementDate'] > end_date))]

# %%
df = df[~((df['ChgOffDate'] < begin_date) | (df['ChgOffDate'] > end_date))]

# %%
## Examine the summary statistics again. Note that the skewed distributions remain.
summary_new = df.describe(percentiles = [0.25, 0.5, 0.75, 0.90, 0.99, 0.999], datetime_is_numeric = True).T
summary_new
# Out:
#                       count                           mean  \
# ApprovalDate         896106  2001-06-07 17:09:45.372712064
# ApprovalFY           896106  2001-03-02 21:38:32.396970624
# Term               896106.0                     110.825179
# NoEmp              896106.0                      11.408932
# CreateJob          896106.0                       8.454303
# RetainedJob        896106.0                      10.820104
# ChgOffDate           161379  2008-08-15 10:32:43.125312512
# DisbursementDate     893939  2001-09-27 04:18:28.311864448
# DisbursementGross  896106.0                  201625.986248
# BalanceGross       896106.0                        2.99955
# ChgOffPrinGr       896106.0                   13453.215322
# GrAppv             896106.0                  193075.328857
# SBA_Appv           896106.0                   149772.49964
#
#                                    min                  25%  \
# ApprovalDate       1980-01-03 00:00:00  1996-11-27 00:00:00
# ApprovalFY         1980-01-01 00:00:00  1997-01-01 00:00:00
# Term                               0.0                 60.0
# NoEmp                              0.0                  2.0
# CreateJob                          0.0                  0.0
# RetainedJob                        0.0                  0.0
# ChgOffDate         1988-10-03 00:00:00  2007-10-06 12:00:00
# DisbursementDate   1980-01-23 00:00:00  1997-05-31 00:00:00
# DisbursementGross               4000.0              42400.0
# BalanceGross                       0.0                  0.0
# ChgOffPrinGr                       0.0                  0.0
# GrAppv                          1000.0              35000.0
# SBA_Appv                         500.0              21250.0
#
#                                    50%                  75%  \
# ApprovalDate       2002-09-27 00:00:00  2006-01-23 00:00:00
# ApprovalFY         2002-01-01 00:00:00  2006-01-01 00:00:00
# Term                              84.0                120.0
# NoEmp                              4.0                 10.0
# CreateJob                          0.0                  1.0
# RetainedJob                        1.0                  4.0
# ChgOffDate         2009-12-15 00:00:00  2011-03-23 00:00:00
# DisbursementDate   2002-12-31 00:00:00  2006-03-31 00:00:00
# DisbursementGross             100000.0             239000.0
# BalanceGross                       0.0                  0.0
# ChgOffPrinGr                       0.0                  0.0
# GrAppv                         90000.0             225000.0
# SBA_Appv                       62000.0             175000.0
#
#                                    90%                  99%  \
# ApprovalDate       2007-11-19 00:00:00  2011-09-23 00:00:00
# ApprovalFY         2008-01-01 00:00:00  2011-01-01 00:00:00
# Term                             240.0                300.0
# NoEmp                             25.0                 95.0
# CreateJob                          5.0                 30.0
# RetainedJob                       11.0                 55.0
# ChgOffDate         2012-09-24 00:00:00  2014-06-19 00:00:00
# DisbursementDate   2008-02-29 00:00:00  2011-12-01 00:00:00
# DisbursementGross             502000.0            1367991.0
# BalanceGross                       0.0                  0.0
# ChgOffPrinGr                   26538.0            274954.85
# GrAppv                        500000.0            1350000.0
# SBA_Appv                      408000.0            1000000.0
#
#                                  99.9%                  max            std
# ApprovalDate       2013-05-07 00:00:00  2014-06-25 00:00:00            NaN
# ApprovalFY         2013-01-01 00:00:00  2014-01-01 00:00:00            NaN
# Term                             309.0                569.0      78.909251
# NoEmp                            300.0               9999.0      73.832562
# CreateJob                        200.0               8800.0     237.090306
# RetainedJob                     279.79               9500.0     237.522597
# ChgOffDate         2014-08-25 00:00:00  2014-08-29 00:00:00            NaN
# DisbursementDate   2013-07-01 00:00:00  2014-12-31 00:00:00            NaN
# DisbursementGross          2084906.655           11446325.0   287933.41382
# BalanceGross                       0.0             996262.0    1444.620528
# ChgOffPrinGr                899596.685            3512596.0   65115.718405
# GrAppv                       2000000.0            5472000.0  283556.407324
# SBA_Appv                     1888895.0            5472000.0  228655.977297

# %%
## Plotting the distributions of the numerical variables, we see that most are too skewed to give interesting histograms.
df.hist(figsize = (20, 15))
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ### Check for duplicates and missing data

# %%
## We check for the number and percentage of missing values in this column.
summary_missing = pd.concat((df.isna().sum(), df.isna().sum()/df.shape[0] * 100), axis = 1)
summary_missing.columns = ['count', 'percent']
summary_missing
# Out:
#                     count    percent
# ID                      0   0.000000
# Name                   14   0.001562
# City                   30   0.003348
# State                  12   0.001339
# Zip                     0   0.000000
# Bank                 1488   0.166052
# BankState            1494   0.166721
# NAICS              200608  22.386637
# ApprovalDate            0   0.000000
# ApprovalFY              0   0.000000
# Term                    0   0.000000
# NoEmp                   0   0.000000
# NewExist             1158   0.129226
# CreateJob               0   0.000000
# RetainedJob             0   0.000000
# FranchiseCode           0   0.000000
# UrbanRural              0   0.000000
# LowDoc               5999   0.669452
# ChgOffDate         734727  81.991081
# DisbursementDate     2167   0.241824
# DisbursementGross       0   0.000000
# BalanceGross            0   0.000000
# MIS_Status              0   0.000000
# ChgOffPrinGr            0   0.000000
# GrAppv                  0   0.000000
# SBA_Appv                0   0.000000

# %% [markdown]
# We primarily have missing data in categorical variables, where there is no easy way to impute. However, missing values are relatively rare in most columns, meaning it is probably safe to drop them.
#
# The exceptions are `ChgOffDate`, where NaN represents a loan that has not declared in default, and NAICS, where about 20% of values are missing.

# %%
## We confirm that the `ID` column acts as a unique identifier.
df['ID'].is_unique
# Out:
# True

# %%
## We check that there are no otherwise identical rows with the same ID.
## Duplicated rows do not seem to be a concern for this dataset.
sum(df.duplicated(subset = list(set(df.columns) - set('ID')), keep = False))
# Out:
# 0

# %% [markdown]
# ### Write the Cleaned Data to a File

# %%
## Save in a separate directory from the original file
df.to_csv(r'./Data/Processed/sba_cleaned.csv', index=False)
